# %%
import pandas as pd
df = pd.read_csv('/Users/mia/Desktop/HY_Universe_corporate bond.csv')

# %%
df.shape
# Out:
# (2721, 37)

# %%
df.size
# Out:
# 100677

# %%
#check data information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 37 columns):
# CUSIP                         2721 non-null object
# Ticker                        2721 non-null object
# Issue Date                    2721 non-null object
# Maturity                      2721 non-null object
# 1st Call Date                 2721 non-null object
# Moodys                        2721 non-null object
# S_and_P                       2721 non-null object
# Fitch                         2721 non-null object
# Bloomberg Composite Rating    2721 non-null object
# Coupon                        2721 non-null float64
# Issued Amount                 2721 non-null float64
# Maturity Type                 2721 non-null object
# Coupon Type                   2721 non-null object
# Maturity At Issue months      2721 non-null float64
# Industry                      2721 non-null object
# LiquidityScore                2721 non-null float64
# ...

# %%
#Visualization of Outliers Using Quantile‐Quantile Plot
#plot1 
import numpy as np 
import pylab 
import scipy.stats as stats

#coupon = np.random.normal(loc = 20, scale = 5, size=100)   
#stats.probplot(coupon, dist="norm", plot=pylab)
#pylab.show()

from scipy import stats
stats.probplot(df.n_trades, dist="norm", plot=plt)
plt.show()

# %%
#Quantile‐Quantile Plot2
from scipy import stats
stats.probplot(df.Client_Trade_Percentage, dist="norm", plot=plt)
plt.show()

# %%
#Using Python Pandas to Read and Summarize Data
#splitting the data and grouping the data
byticker = df.groupby(["Ticker", "1st Call Date"])
byticker["percent_intra_dealer"].describe()
# Out:
#                       count      mean       std       min       25%       50%  \
# Ticker 1st Call Date
# AA     9/30/2019        1.0  0.235075       NaN  0.235075  0.235075  0.235075
#        9/30/2021        1.0  0.322270       NaN  0.322270  0.322270  0.322270
# AAL    Nan              8.0  0.280930  0.160650  0.000000  0.206250  0.264058
# AALLN  Nan             10.0  0.284417  0.050075  0.205128  0.250403  0.290079
# AAPL   Nan              1.0  0.351852       NaN  0.351852  0.351852  0.351852
# ABBEY  Nan              1.0  0.229730       NaN  0.229730  0.229730  0.229730
# ABBNVX Nan              1.0  0.484848       NaN  0.484848  0.484848  0.484848
# ABBV   Nan              1.0  0.000000       NaN  0.000000  0.000000  0.000000
# ABCBBZ Nan              1.0  0.041096       NaN  0.041096  0.041096  0.041096
# ABCSUP 10/23/2017       1.0  0.093664       NaN  0.093664  0.093664  0.093664
# ABG    12/15/2019       1.0  0.277017       NaN  0.277017  0.277017  0.277017
# ...

# %%
byticker = df.groupby("Ticker")
byticker["percent_intra_dealer"].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Ticker
# AA        2.0  0.278672  0.061656  0.235075  0.256873  0.278672  0.300471
# AAL       8.0  0.280930  0.160650  0.000000  0.206250  0.264058  0.377143
# AALLN    10.0  0.284417  0.050075  0.205128  0.250403  0.290079  0.309485
# AAPL      1.0  0.351852       NaN  0.351852  0.351852  0.351852  0.351852
# ABBEY     1.0  0.229730       NaN  0.229730  0.229730  0.229730  0.229730
# ABBNVX    1.0  0.484848       NaN  0.484848  0.484848  0.484848  0.484848
# ABBV      1.0  0.000000       NaN  0.000000  0.000000  0.000000  0.000000
# ABCBBZ    1.0  0.041096       NaN  0.041096  0.041096  0.041096  0.041096
# ABCSUP    1.0  0.093664       NaN  0.093664  0.093664  0.093664  0.093664
# ABG       2.0  0.144919  0.186815  0.012821  0.078870  0.144919  0.210968
# ABGSM     2.0  0.110405  0.005104  0.106796  0.108601  0.110405  0.112210
# ABH       2.0  0.145374  0.205591  0.000000  0.072687  0.145374  0.218062
# ...

# %%
#Listing 2-6: Parallel Coordinates Graph for Real Attribute Visualization—linePlots.py
import matplotlib.pyplot as plt
char = df[['Issue Date','Moodys','S_and_P']][:20]

parallel_coordinates(char, 'Moodys')
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.1),ncol=2,fancybox=True,shadow=True)
plt.show()

# %%
#listing 2-7 Cross Plotting Pairs of Attributes - creating scatter plots 
import numpy as np
import matplotlib.pyplot as plt
x = df['Client_Trade_Percentage']
y = df['percent_uncapped']


# Plot1
area = np.pi*3
plt.scatter(x, y, s=area, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# plot2
x1 = df["n_trades"]
x2 = df["LIQ SCORE"]
plt.scatter(x1,x2)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
#listing 2-8 Correlation between Classification Target and Real Attributes
correlations = pd.DataFrame(df.corr())
correlations
# Out:
#                             Coupon  Issued Amount  Maturity At Issue months  \
# Coupon                    1.000000      -0.014238                  0.098844
# Issued Amount            -0.014238       1.000000                  0.008601
# Maturity At Issue months  0.098844       0.008601                  1.000000
# LiquidityScore           -0.042302       0.134930                  0.072507
# LIQ SCORE                -0.042302       0.134930                  0.072507
# n_trades                 -0.023330       0.156948                  0.038839
# volume_trades            -0.026717       0.326310                 -0.015227
# total_median_size         0.044601       0.062343                 -0.115086
# total_mean_size           0.026891       0.078362                 -0.138581
# n_days_trade             -0.028336       0.068113                  0.029530
# days_diff_max            -0.025089      -0.008097                  0.103178
# ...

# %%
# create a heatmap 
import seaborn as sns
x = sns.heatmap(correlations)

# %%
#create a boxplot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
sns.boxplot(df["Moodys"][:40], df["Coupon"][:30], data=df)
plt.show()

# %%
print("My name is Wanbin Cao")
print("My NetID is: wcao11")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
# Out:
# My name is Wanbin Cao
# My NetID is: wcao11
# I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.
